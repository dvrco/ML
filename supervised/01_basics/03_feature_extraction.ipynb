# %% [markdown]
# <a href="https://colab.research.google.com/github/dvrco/ML/blob/main/supervised/01_basics/03_feature_extraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import sklearn

sklearn.__version__
# Out:
# '1.2.2'

# %%
def fetch_financial_data(company='TELL'):
    """
    This function fetches stock market quotations.
    """
    import pandas_datareader.data as web
    return web.DataReader(name=company, data_source='stooq')

df_raw = fetch_financial_data()
df_raw.head()
# Out:
#               Open      High       Low   Close    Volume
# Date
# 2023-11-24  0.5168  0.534001  0.513000  0.5282  29774316
# 2023-11-22  0.5196  0.525400  0.483134  0.5223  43755983
# 2023-11-21  0.5365  0.539900  0.496600  0.5086  48113656
# 2023-11-20  0.5468  0.559800  0.525200  0.5300  59682027
# 2023-11-17  0.5521  0.555000  0.528300  0.5386  33653790

# %%
df = df_raw.copy()
df = df[:5]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5 entries, 2023-11-24 to 2023-11-17
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    5 non-null      float64
#  1   High    5 non-null      float64
#  2   Low     5 non-null      float64
#  3   Close   5 non-null      float64
#  4   Volume  5 non-null      int64
# dtypes: float64(4), int64(1)
# memory usage: 240.0 bytes

# %%
### generowanie nowych zmiennych
df['day'] = df.index.day
df['month'] = df.index.month
df['year'] = df.index.year
df
# Out:
#               Open      High       Low   Close    Volume  day  month  year
# Date
# 2023-11-24  0.5168  0.534001  0.513000  0.5282  29774316   24     11  2023
# 2023-11-22  0.5196  0.525400  0.483134  0.5223  43755983   22     11  2023
# 2023-11-21  0.5365  0.539900  0.496600  0.5086  48113656   21     11  2023
# 2023-11-20  0.5468  0.559800  0.525200  0.5300  59682027   20     11  2023
# 2023-11-17  0.5521  0.555000  0.528300  0.5386  33653790   17     11  2023

# %%
df.index.day
# Out:
# Int64Index([24, 22, 21, 20, 17], dtype='int64', name='Date')

# %%
df = pd.DataFrame(data={'height': [175., 178.5, 185., 191., 184.5, 183., 168.]})
df
# Out:
#    height
# 0   175.0
# 1   178.5
# 2   185.0
# 3   191.0
# 4   184.5
# 5   183.0
# 6   168.0

# %%
df['heigh_cat'] = pd.cut(x=df.height, bins=3)
df
# Out:
#    height           heigh_cat
# 0   175.0  (167.977, 175.667]
# 1   178.5  (175.667, 183.333]
# 2   185.0    (183.333, 191.0]
# 3   191.0    (183.333, 191.0]
# 4   184.5    (183.333, 191.0]
# 5   183.0  (175.667, 183.333]
# 6   168.0  (167.977, 175.667]

# %%
df['height_cat'] = pd.cut(x=df.height, bins=(160, 175, 180, 195), labels=['small', 'medium', 'height'])
df
# Out:
#    height height_cat
# 0   175.0      small
# 1   178.5     medium
# 2   185.0     height
# 3   191.0     height
# 4   184.5     height
# 5   183.0     height
# 6   168.0      small

# %%
pd.get_dummies(df, drop_first=True, prefix='height')
# Out:
#    height  height_medium  height_height
# 0   175.0              0              0
# 1   178.5              1              0
# 2   185.0              0              1
# 3   191.0              0              1
# 4   184.5              0              1
# 5   183.0              0              1
# 6   168.0              0              0

# %%
### eksracja cech
df = pd.DataFrame(data={'lang': [['PL', 'ENG'], ['GER', 'ENG', 'PL', 'FRA'], ['RUS']]})
df
# Out:
#                   lang
# 0            [PL, ENG]
# 1  [GER, ENG, PL, FRA]
# 2                [RUS]

# %%
df['lang_number'] = df['lang'].apply(len)
df
# Out:
#                   lang  lang_number
# 0            [PL, ENG]            2
# 1  [GER, ENG, PL, FRA]            4
# 2                [RUS]            1

# %%
df['PL_flag'] = df['lang'].apply(lambda x: 1 if 'PL' in x else 0)
df
# Out:
#                   lang  lang_number  PL_flag
# 0            [PL, ENG]            2        1
# 1  [GER, ENG, PL, FRA]            4        1
# 2                [RUS]            1        0

# %%
df = pd.DataFrame(data={'website': ['wp.pl', 'onet.pl', 'google.com']})
df
# Out:
#       website
# 0       wp.pl
# 1     onet.pl
# 2  google.com

# %%
df.website.str.split('.', expand=True)
# Out:
#         0    1
# 0      wp   pl
# 1    onet   pl
# 2  google  com

# %%
new = df.website.str.split('.', expand=True)
df['portal'] = new[0]
df['extension'] = new[1]
df
# Out:
#       website  portal extension
# 0       wp.pl      wp        pl
# 1     onet.pl    onet        pl
# 2  google.com  google       com
